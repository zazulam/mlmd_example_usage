# %%
import ml_metadata
from ml_metadata import metadata_store
from ml_metadata.proto import metadata_store_pb2
from google.protobuf import json_format

# %%
connection_config = metadata_store_pb2.ConnectionConfig()
connection_config.mysql.host = '127.0.0.1'
connection_config.mysql.port = 3306
connection_config.mysql.database = 'metadb' 
connection_config.mysql.user = 'root'

# %%
store = metadata_store.MetadataStore(connection_config)

# %%
# Step 1: Let's assume we have a RUN ID (DAG ID) to start with
run_id = "34c07c09-8485-4192-8e31-697208277a7a"
# the run containing the iris dataset we were exploring in the previous slides

# %%
# Step 2: Let's query the mlmd to get the execution ID associated with this run
run_execution_id = store.get_executions(
    list_options = ml_metadata.ListOptions(
        filter_query=f'name="run/{run_id}"'
    )
)[0].id
run_execution_id
# Out:
# 257

# %%
# Step 3: Grab all the pod executions from that run execution
container_executions = store.get_executions(
    list_options = ml_metadata.ListOptions(
        filter_query=f'custom_properties.parent_dag_id.int_value={run_execution_id}'
    )
)

# %%
container_execution_ids = [container.id for container in container_executions]
container_execution_ids
# Out:
# [258, 259, 260]

# %%
events = store.get_events_by_execution_ids(
            execution_ids=container_execution_ids
        )
artifact_ids = [event.artifact_id for event in events]

artifacts = store.get_artifacts_by_id(artifact_ids)
artifacts
# Out:
# [id: 2
#  type_id: 16
#  uri: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/create-dataset/iris_dataset"
#  custom_properties {
#    key: "display_name"
#    value {
#      string_value: "iris_dataset"
#    }
#  }
#  state: LIVE
#  type: "system.Dataset"
#  create_time_since_epoch: 1724782514643
#  last_update_time_since_epoch: 1724782514643,
#  id: 3
#  type_id: 16
#  uri: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/normalize-dataset/normalized_iris_dataset"
#  custom_properties {
#    key: "display_name"
#    value {
#      string_value: "normalized_iris_dataset"
#    }
#  }
#  state: LIVE
#  type: "system.Dataset"
#  create_time_since_epoch: 1724782554534
#  last_update_time_since_epoch: 1724782554534]

# %%
json_artifacts = [json_format.MessageToDict(artifact) for artifact in artifacts]
json_artifacts
# Out:
# [{'id': '2',
#   'typeId': '16',
#   'uri': 'minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/create-dataset/iris_dataset',
#   'customProperties': {'display_name': {'stringValue': 'iris_dataset'}},
#   'state': 'LIVE',
#   'type': 'system.Dataset',
#   'createTimeSinceEpoch': '1724782514643',
#   'lastUpdateTimeSinceEpoch': '1724782514643'},
#  {'id': '3',
#   'typeId': '16',
#   'uri': 'minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/normalize-dataset/normalized_iris_dataset',
#   'customProperties': {'display_name': {'stringValue': 'normalized_iris_dataset'}},
#   'state': 'LIVE',
#   'type': 'system.Dataset',
#   'createTimeSinceEpoch': '1724782554534',
#   'lastUpdateTimeSinceEpoch': '1724782554534'}]

# %%
from paleonotology import KFPaleontologist
paleontologist = KFPaleontologist(connection_config)

# %%
artifacts = paleontologist.get_artifacts_from_run(run_id)
artifacts
# Out:
# [id: 2
#  type_id: 16
#  uri: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/create-dataset/iris_dataset"
#  custom_properties {
#    key: "display_name"
#    value {
#      string_value: "iris_dataset"
#    }
#  }
#  state: LIVE
#  type: "system.Dataset"
#  create_time_since_epoch: 1724782514643
#  last_update_time_since_epoch: 1724782514643,
#  id: 3
#  type_id: 16
#  uri: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/normalize-dataset/normalized_iris_dataset"
#  custom_properties {
#    key: "display_name"
#    value {
#      string_value: "normalized_iris_dataset"
#    }
#  }
#  state: LIVE
#  type: "system.Dataset"
#  create_time_since_epoch: 1724782554534
#  last_update_time_since_epoch: 1724782554534]

# %%
artifact_history = paleontologist.get_artifact_execution_history(artifacts[0].id)

print(f"number of execs related to artifact: {len(artifact_history)}")
for exec in artifact_history:
    print(exec)
# Out:
# number of execs related to artifact: 2
# id: 258
# type_id: 14
# last_known_state: COMPLETE
# custom_properties {
#   key: "display_name"
#   value {
#     string_value: "create-dataset"
#   }
# }
# custom_properties {
#   key: "image"
#   value {
#     string_value: ""
#   }
# }
# custom_properties {
#   key: "inputs"
#   value {
#     struct_value {
#     }
#   }
# }
# custom_properties {
#   key: "namespace"
#   value {
#     string_value: "kubeflow"
#   }
# }
# custom_properties {
#   key: "outputs"
#   value {
#     struct_value {
#     }
#   }
# }
# custom_properties {
#   key: "parent_dag_id"
#   value {
#     int_value: 257
#   }
# }
# custom_properties {
#   key: "pod_name"
#   value {
#     string_value: "iris-training-pipeline-84xw9-system-container-impl-2685640547"
#   }
# }
# custom_properties {
#   key: "pod_uid"
#   value {
#     string_value: "ceb0bcfd-6844-464f-ade1-023c8dcec331"
#   }
# }
# custom_properties {
#   key: "task_name"
#   value {
#     string_value: "create-dataset"
#   }
# }
# type: "system.ContainerExecution"
# create_time_since_epoch: 1724782486499
# last_update_time_since_epoch: 1724782514658
#
# id: 259
# type_id: 14
# last_known_state: COMPLETE
# custom_properties {
#   key: "display_name"
#   value {
#     string_value: "normalize-dataset"
#   }
# }
# custom_properties {
#   key: "image"
#   value {
#     string_value: ""
#   }
# }
# custom_properties {
#   key: "inputs"
#   value {
#     struct_value {
#       fields {
#         key: "min_max_scaler"
#         value {
#           bool_value: false
#         }
#       }
#       fields {
#         key: "standard_scaler"
#         value {
#           bool_value: true
#         }
#       }
#     }
#   }
# }
# custom_properties {
#   key: "namespace"
#   value {
#     string_value: "kubeflow"
#   }
# }
# custom_properties {
#   key: "outputs"
#   value {
#     struct_value {
#     }
#   }
# }
# custom_properties {
#   key: "parent_dag_id"
#   value {
#     int_value: 257
#   }
# }
# custom_properties {
#   key: "pod_name"
#   value {
#     string_value: "iris-training-pipeline-84xw9-system-container-impl-1876992316"
#   }
# }
# custom_properties {
#   key: "pod_uid"
#   value {
#     string_value: "06ef9410-e118-4326-a747-5109eab7c93d"
#   }
# }
# custom_properties {
#   key: "task_name"
#   value {
#     string_value: "normalize-dataset"
#   }
# }
# type: "system.ContainerExecution"
# create_time_since_epoch: 1724782527864
# last_update_time_since_epoch: 1724782554546

# %%
lineage = paleontologist.get_artifact_lineage(artifacts[0].id)
lineage
# Out:
# WARNING: Logging before InitGoogleLogging() is written to STDERR
# I1009 14:51:04.427124 50490 rdbms_metadata_access_object.cc:3129] max_num_hops is not set. Using maximum value: 100 to limit the steps of the traversal.
# artifact_types {
#   id: 16
#   name: "system.Dataset"
# }
# artifact_types {
#   id: 17
#   name: "system.Model"
# }
# execution_types {
#   id: 13
#   name: "system.DAGExecution"
# }
# execution_types {
#   id: 14
#   name: "system.ContainerExecution"
# }
# context_types {
#   id: 11
#   name: "system.Pipeline"
# }
# context_types {
#   id: 12
#   name: "system.PipelineRun"
# }
# artifacts {
#   id: 2
#   type_id: 16
#   uri: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/create-dataset/iris_dataset"
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "iris_dataset"
#     }
#   }
#   state: LIVE
#   type: "system.Dataset"
#   create_time_since_epoch: 1724782514643
#   last_update_time_since_epoch: 1724782514643
# }
# artifacts {
#   id: 3
#   type_id: 16
#   uri: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/normalize-dataset/normalized_iris_dataset"
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "normalized_iris_dataset"
#     }
#   }
#   state: LIVE
#   type: "system.Dataset"
#   create_time_since_epoch: 1724782554534
#   last_update_time_since_epoch: 1724782554534
# }
# artifacts {
#   id: 4
#   type_id: 17
#   uri: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/train-model/model"
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "model"
#     }
#   }
#   state: LIVE
#   type: "system.Model"
#   create_time_since_epoch: 1724782624925
#   last_update_time_since_epoch: 1724782624925
# }
# artifacts {
#   id: 5
#   type_id: 17
#   uri: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/train-model/model"
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "model"
#     }
#   }
#   state: LIVE
#   type: "system.Model"
#   create_time_since_epoch: 1724782624962
#   last_update_time_since_epoch: 1724782624962
# }
# artifacts {
#   id: 6
#   type_id: 17
#   uri: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a/train-model/model"
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "model"
#     }
#   }
#   state: LIVE
#   type: "system.Model"
#   create_time_since_epoch: 1724782625147
#   last_update_time_since_epoch: 1724782625147
# }
# executions {
#   id: 258
#   type_id: 14
#   last_known_state: COMPLETE
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "create-dataset"
#     }
#   }
#   custom_properties {
#     key: "image"
#     value {
#       string_value: ""
#     }
#   }
#   custom_properties {
#     key: "inputs"
#     value {
#       struct_value {
#       }
#     }
#   }
#   custom_properties {
#     key: "namespace"
#     value {
#       string_value: "kubeflow"
#     }
#   }
#   custom_properties {
#     key: "outputs"
#     value {
#       struct_value {
#       }
#     }
#   }
#   custom_properties {
#     key: "parent_dag_id"
#     value {
#       int_value: 257
#     }
#   }
#   custom_properties {
#     key: "pod_name"
#     value {
#       string_value: "iris-training-pipeline-84xw9-system-container-impl-2685640547"
#     }
#   }
#   custom_properties {
#     key: "pod_uid"
#     value {
#       string_value: "ceb0bcfd-6844-464f-ade1-023c8dcec331"
#     }
#   }
#   custom_properties {
#     key: "task_name"
#     value {
#       string_value: "create-dataset"
#     }
#   }
#   type: "system.ContainerExecution"
#   create_time_since_epoch: 1724782486499
#   last_update_time_since_epoch: 1724782514658
# }
# executions {
#   id: 259
#   type_id: 14
#   last_known_state: COMPLETE
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "normalize-dataset"
#     }
#   }
#   custom_properties {
#     key: "image"
#     value {
#       string_value: ""
#     }
#   }
#   custom_properties {
#     key: "inputs"
#     value {
#       struct_value {
#         fields {
#           key: "min_max_scaler"
#           value {
#             bool_value: false
#           }
#         }
#         fields {
#           key: "standard_scaler"
#           value {
#             bool_value: true
#           }
#         }
#       }
#     }
#   }
#   custom_properties {
#     key: "namespace"
#     value {
#       string_value: "kubeflow"
#     }
#   }
#   custom_properties {
#     key: "outputs"
#     value {
#       struct_value {
#       }
#     }
#   }
#   custom_properties {
#     key: "parent_dag_id"
#     value {
#       int_value: 257
#     }
#   }
#   custom_properties {
#     key: "pod_name"
#     value {
#       string_value: "iris-training-pipeline-84xw9-system-container-impl-1876992316"
#     }
#   }
#   custom_properties {
#     key: "pod_uid"
#     value {
#       string_value: "06ef9410-e118-4326-a747-5109eab7c93d"
#     }
#   }
#   custom_properties {
#     key: "task_name"
#     value {
#       string_value: "normalize-dataset"
#     }
#   }
#   type: "system.ContainerExecution"
#   create_time_since_epoch: 1724782527864
#   last_update_time_since_epoch: 1724782554546
# }
# executions {
#   id: 260
#   type_id: 13
#   last_known_state: RUNNING
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "for-loop-1"
#     }
#   }
#   custom_properties {
#     key: "inputs"
#     value {
#       struct_value {
#         fields {
#           key: "pipelinechannel--neighbors"
#           value {
#             list_value {
#               values {
#                 number_value: 4.0
#               }
#               values {
#                 number_value: 8.0
#               }
#               values {
#                 number_value: 12.0
#               }
#             }
#           }
#         }
#       }
#     }
#   }
#   custom_properties {
#     key: "iteration_count"
#     value {
#       int_value: 3
#     }
#   }
#   custom_properties {
#     key: "parent_dag_id"
#     value {
#       int_value: 257
#     }
#   }
#   custom_properties {
#     key: "task_name"
#     value {
#       string_value: "for-loop-1"
#     }
#   }
#   type: "system.DAGExecution"
#   create_time_since_epoch: 1724782574368
#   last_update_time_since_epoch: 1724782574368
# }
# executions {
#   id: 261
#   type_id: 13
#   last_known_state: RUNNING
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "for-loop-1"
#     }
#   }
#   custom_properties {
#     key: "inputs"
#     value {
#       struct_value {
#         fields {
#           key: "pipelinechannel--neighbors-loop-item"
#           value {
#             number_value: 8.0
#           }
#         }
#       }
#     }
#   }
#   custom_properties {
#     key: "iteration_index"
#     value {
#       int_value: 1
#     }
#   }
#   custom_properties {
#     key: "parent_dag_id"
#     value {
#       int_value: 260
#     }
#   }
#   custom_properties {
#     key: "task_name"
#     value {
#       string_value: "for-loop-1"
#     }
#   }
#   type: "system.DAGExecution"
#   create_time_since_epoch: 1724782585478
#   last_update_time_since_epoch: 1724782585478
# }
# executions {
#   id: 262
#   type_id: 13
#   last_known_state: RUNNING
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "for-loop-1"
#     }
#   }
#   custom_properties {
#     key: "inputs"
#     value {
#       struct_value {
#         fields {
#           key: "pipelinechannel--neighbors-loop-item"
#           value {
#             number_value: 4.0
#           }
#         }
#       }
#     }
#   }
#   custom_properties {
#     key: "iteration_index"
#     value {
#       int_value: 0
#     }
#   }
#   custom_properties {
#     key: "parent_dag_id"
#     value {
#       int_value: 260
#     }
#   }
#   custom_properties {
#     key: "task_name"
#     value {
#       string_value: "for-loop-1"
#     }
#   }
#   type: "system.DAGExecution"
#   create_time_since_epoch: 1724782585478
#   last_update_time_since_epoch: 1724782585478
# }
# executions {
#   id: 263
#   type_id: 13
#   last_known_state: RUNNING
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "for-loop-1"
#     }
#   }
#   custom_properties {
#     key: "inputs"
#     value {
#       struct_value {
#         fields {
#           key: "pipelinechannel--neighbors-loop-item"
#           value {
#             number_value: 12.0
#           }
#         }
#       }
#     }
#   }
#   custom_properties {
#     key: "iteration_index"
#     value {
#       int_value: 2
#     }
#   }
#   custom_properties {
#     key: "parent_dag_id"
#     value {
#       int_value: 260
#     }
#   }
#   custom_properties {
#     key: "task_name"
#     value {
#       string_value: "for-loop-1"
#     }
#   }
#   type: "system.DAGExecution"
#   create_time_since_epoch: 1724782585483
#   last_update_time_since_epoch: 1724782585483
# }
# executions {
#   id: 264
#   type_id: 14
#   last_known_state: COMPLETE
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "train-model"
#     }
#   }
#   custom_properties {
#     key: "image"
#     value {
#       string_value: ""
#     }
#   }
#   custom_properties {
#     key: "inputs"
#     value {
#       struct_value {
#         fields {
#           key: "n_neighbors"
#           value {
#             number_value: 8.0
#           }
#         }
#       }
#     }
#   }
#   custom_properties {
#     key: "namespace"
#     value {
#       string_value: "kubeflow"
#     }
#   }
#   custom_properties {
#     key: "outputs"
#     value {
#       struct_value {
#       }
#     }
#   }
#   custom_properties {
#     key: "parent_dag_id"
#     value {
#       int_value: 261
#     }
#   }
#   custom_properties {
#     key: "pod_name"
#     value {
#       string_value: "iris-training-pipeline-84xw9-system-container-impl-4014276833"
#     }
#   }
#   custom_properties {
#     key: "pod_uid"
#     value {
#       string_value: "3f88e4cf-2bbd-4497-892c-2444fc040ca6"
#     }
#   }
#   custom_properties {
#     key: "task_name"
#     value {
#       string_value: "train-model"
#     }
#   }
#   type: "system.ContainerExecution"
#   create_time_since_epoch: 1724782594518
#   last_update_time_since_epoch: 1724782624939
# }
# executions {
#   id: 265
#   type_id: 14
#   last_known_state: COMPLETE
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "train-model"
#     }
#   }
#   custom_properties {
#     key: "image"
#     value {
#       string_value: ""
#     }
#   }
#   custom_properties {
#     key: "inputs"
#     value {
#       struct_value {
#         fields {
#           key: "n_neighbors"
#           value {
#             number_value: 12.0
#           }
#         }
#       }
#     }
#   }
#   custom_properties {
#     key: "namespace"
#     value {
#       string_value: "kubeflow"
#     }
#   }
#   custom_properties {
#     key: "outputs"
#     value {
#       struct_value {
#       }
#     }
#   }
#   custom_properties {
#     key: "parent_dag_id"
#     value {
#       int_value: 263
#     }
#   }
#   custom_properties {
#     key: "pod_name"
#     value {
#       string_value: "iris-training-pipeline-84xw9-system-container-impl-2656384933"
#     }
#   }
#   custom_properties {
#     key: "pod_uid"
#     value {
#       string_value: "adc4e0f4-7b17-4dc4-87b1-1a1456e0b026"
#     }
#   }
#   custom_properties {
#     key: "task_name"
#     value {
#       string_value: "train-model"
#     }
#   }
#   type: "system.ContainerExecution"
#   create_time_since_epoch: 1724782594546
#   last_update_time_since_epoch: 1724782625160
# }
# executions {
#   id: 266
#   type_id: 14
#   last_known_state: COMPLETE
#   custom_properties {
#     key: "display_name"
#     value {
#       string_value: "train-model"
#     }
#   }
#   custom_properties {
#     key: "image"
#     value {
#       string_value: ""
#     }
#   }
#   custom_properties {
#     key: "inputs"
#     value {
#       struct_value {
#         fields {
#           key: "n_neighbors"
#           value {
#             number_value: 4.0
#           }
#         }
#       }
#     }
#   }
#   custom_properties {
#     key: "namespace"
#     value {
#       string_value: "kubeflow"
#     }
#   }
#   custom_properties {
#     key: "outputs"
#     value {
#       struct_value {
#       }
#     }
#   }
#   custom_properties {
#     key: "parent_dag_id"
#     value {
#       int_value: 262
#     }
#   }
#   custom_properties {
#     key: "pod_name"
#     value {
#       string_value: "iris-training-pipeline-84xw9-system-container-impl-2559777277"
#     }
#   }
#   custom_properties {
#     key: "pod_uid"
#     value {
#       string_value: "54a4715a-6f71-47de-b432-deceb6274537"
#     }
#   }
#   custom_properties {
#     key: "task_name"
#     value {
#       string_value: "train-model"
#     }
#   }
#   type: "system.ContainerExecution"
#   create_time_since_epoch: 1724782594569
#   last_update_time_since_epoch: 1724782624975
# }
# contexts {
#   id: 29
#   type_id: 11
#   name: "iris-training-pipeline"
#   type: "system.Pipeline"
#   create_time_since_epoch: 1724769885035
#   last_update_time_since_epoch: 1724769885035
# }
# contexts {
#   id: 37
#   type_id: 12
#   name: "34c07c09-8485-4192-8e31-697208277a7a"
#   custom_properties {
#     key: "namespace"
#     value {
#       string_value: "kubeflow"
#     }
#   }
#   custom_properties {
#     key: "pipeline_root"
#     value {
#       string_value: "minio://mlpipeline/v2/artifacts/iris-training-pipeline/34c07c09-8485-4192-8e31-697208277a7a"
#     }
#   }
#   custom_properties {
#     key: "resource_name"
#     value {
#       string_value: "run-resource"
#     }
#   }
#   custom_properties {
#     key: "store_session_info"
#     value {
#       string_value: "{\"Provider\":\"minio\",\"Params\":{\"accessKeyKey\":\"accesskey\",\"disableSSL\":\"true\",\"endpoint\":\"10.96.103.164:9000\",\"fromEnv\":\"false\",\"region\":\"minio\",\"secretKeyKey\":\"secretkey\",\"secretName\":\"mlpipeline-minio-artifact\"}}"
#     }
#   }
#   type: "system.PipelineRun"
#   create_time_since_epoch: 1724782476389
#   last_update_time_since_epoch: 1724782476389
# }
# events {
#   artifact_id: 2
#   execution_id: 258
#   path {
#     steps {
#       key: "iris_dataset"
#     }
#   }
#   type: OUTPUT
#   milliseconds_since_epoch: 1724782514659
# }
# events {
#   artifact_id: 2
#   execution_id: 259
#   path {
#     steps {
#       key: "input_iris_dataset"
#     }
#   }
#   type: INPUT
#   milliseconds_since_epoch: 1724782527865
# }
# events {
#   artifact_id: 3
#   execution_id: 259
#   path {
#     steps {
#       key: "normalized_iris_dataset"
#     }
#   }
#   type: OUTPUT
#   milliseconds_since_epoch: 1724782554547
# }
# events {
#   artifact_id: 3
#   execution_id: 260
#   path {
#     steps {
#       key: "pipelinechannel--normalize-dataset-normalized_iris_dataset"
#     }
#   }
#   type: INPUT
#   milliseconds_since_epoch: 1724782574369
# }
# events {
#   artifact_id: 3
#   execution_id: 261
#   path {
#     steps {
#       key: "pipelinechannel--normalize-dataset-normalized_iris_dataset"
#     }
#   }
#   type: INPUT
#   milliseconds_since_epoch: 1724782585478
# }
# events {
#   artifact_id: 3
#   execution_id: 262
#   path {
#     steps {
#       key: "pipelinechannel--normalize-dataset-normalized_iris_dataset"
#     }
#   }
#   type: INPUT
#   milliseconds_since_epoch: 1724782585479
# }
# events {
#   artifact_id: 3
#   execution_id: 263
#   path {
#     steps {
#       key: "pipelinechannel--normalize-dataset-normalized_iris_dataset"
#     }
#   }
#   type: INPUT
#   milliseconds_since_epoch: 1724782585484
# }
# events {
#   artifact_id: 3
#   execution_id: 264
#   path {
#     steps {
#       key: "normalized_iris_dataset"
#     }
#   }
#   type: INPUT
#   milliseconds_since_epoch: 1724782594519
# }
# events {
#   artifact_id: 3
#   execution_id: 265
#   path {
#     steps {
#       key: "normalized_iris_dataset"
#     }
#   }
#   type: INPUT
#   milliseconds_since_epoch: 1724782594547
# }
# events {
#   artifact_id: 3
#   execution_id: 266
#   path {
#     steps {
#       key: "normalized_iris_dataset"
#     }
#   }
#   type: INPUT
#   milliseconds_since_epoch: 1724782594570
# }
# events {
#   artifact_id: 4
#   execution_id: 264
#   path {
#     steps {
#       key: "model"
#     }
#   }
#   type: OUTPUT
#   milliseconds_since_epoch: 1724782624939
# }
# events {
#   artifact_id: 6
#   execution_id: 265
#   path {
#     steps {
#       key: "model"
#     }
#   }
#   type: OUTPUT
#   milliseconds_since_epoch: 1724782625161
# }
# events {
#   artifact_id: 5
#   execution_id: 266
#   path {
#     steps {
#       key: "model"
#     }
#   }
#   type: OUTPUT
#   milliseconds_since_epoch: 1724782624975
# }
# attributions {
#   artifact_id: 2
#   context_id: 29
# }
# attributions {
#   artifact_id: 3
#   context_id: 29
# }
# attributions {
#   artifact_id: 4
#   context_id: 29
# }
# attributions {
#   artifact_id: 5
#   context_id: 29
# }
# attributions {
#   artifact_id: 6
#   context_id: 29
# }
# attributions {
#   artifact_id: 2
#   context_id: 37
# }
# attributions {
#   artifact_id: 3
#   context_id: 37
# }
# attributions {
#   artifact_id: 4
#   context_id: 37
# }
# attributions {
#   artifact_id: 5
#   context_id: 37
# }
# attributions {
#   artifact_id: 6
#   context_id: 37
# }
# associations {
#   execution_id: 258
#   context_id: 29
# }
# associations {
#   execution_id: 259
#   context_id: 29
# }
# associations {
#   execution_id: 260
#   context_id: 29
# }
# associations {
#   execution_id: 261
#   context_id: 29
# }
# associations {
#   execution_id: 262
#   context_id: 29
# }
# associations {
#   execution_id: 263
#   context_id: 29
# }
# associations {
#   execution_id: 264
#   context_id: 29
# }
# associations {
#   execution_id: 265
#   context_id: 29
# }
# associations {
#   execution_id: 266
#   context_id: 29
# }
# associations {
#   execution_id: 258
#   context_id: 37
# }
# associations {
#   execution_id: 259
#   context_id: 37
# }
# associations {
#   execution_id: 260
#   context_id: 37
# }
# associations {
#   execution_id: 261
#   context_id: 37
# }
# associations {
#   execution_id: 262
#   context_id: 37
# }
# associations {
#   execution_id: 263
#   context_id: 37
# }
# associations {
#   execution_id: 264
#   context_id: 37
# }
# associations {
#   execution_id: 265
#   context_id: 37
# }
# associations {
#   execution_id: 266
#   context_id: 37
# }

# %%
paleontologist.visualize_lineage(lineage)
# Out:
# Error: no "view" mailcap rules found for type "application/pdf"
# WARNING: You don't seem to have any mimeinfo.cache files.
# Try running the update-desktop-database command. If you
# don't have this command you should install the
# desktop-file-utils package. This package is available from
# http://freedesktop.org/wiki/Software/desktop-file-utils/
# Can't call method "get_value" on an undefined value at /usr/bin/mimeopen line 159.

# %%
paleontologist.visualize_lineage(lineage,display_association=True, display_attribution=True)
